# %% [markdown]
# <a href="https://colab.research.google.com/github/Trust-in-depth/Network-structure/blob/main/GraphCodeBERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
